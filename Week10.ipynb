# %% [markdown]
# <a href="https://colab.research.google.com/github/UTExDrake/AI_Basic/blob/main/Week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model
model = load_model('/content/drive/MyDrive/Cifar_AI/AI_Week10_Cifar100.h5')

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.utils.image_utils import img_to_array
img = load_img('/content/drive/MyDrive/Cifar_AI/road-1072821__480.jpg',target_size = (32,32))
plt.imshow(img)
plt.show()

# %%
from keras.utils.image_utils import img_to_array
img = img_to_array(img)
img =img.reshape(1,32*32*3)
img = img.astype('float32')
img = img /255
np.argmax(model.predict(img), axis = -1)
# Out:
# 1/1 [==============================] - 0s 144ms/step
# array([26])

# %%
from matplotlib.image import imread
folder = '/content/drive/MyDrive/Cifar_AI'

# %%
for i in range(20):
  plt.subplot(6,5,i+1)
  filename = folder + '/'+ 'A' + str(i) + '.jpg'
  plt.title('So {}'.format([i]))
  img = imread(filename)
  plt.imshow(img)
plt.show()
