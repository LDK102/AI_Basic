# %% [markdown]
# <a href="https://colab.research.google.com/github/UTExDrake/AI_Basic/blob/main/MT_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 42.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = 'Anh_lop.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
i = 0
for face in faces:
  print(face)
  i = i +1 
  print(i)
# Out:
# ...
# 6/6 [==============================] - 1s 57ms/step
# {'box': [1012, 480, 75, 88], 'confidence': 0.9999992251396179, 'keypoints': {'left_eye': (1033, 508), 'right_eye': (1069, 510), 'nose': (1052, 527), 'mouth_left': (1035, 545), 'mouth_right': (1064, 547)}}
# 1
# {'box': [303, 384, 84, 96], 'confidence': 0.9999989867210388, 'keypoints': {'left_eye': (324, 414), 'right_eye': (362, 415), 'nose': (341, 430), 'mouth_left': (326, 452), 'mouth_right': (361, 452)}}
# 2
# {'box': [849, 446, 78, 101], 'confidence': 0.9999976754188538, 'keypoints': {'left_eye': (874, 483), 'right_eye': (908, 488), 'nose': (890, 507), 'mouth_left': (870, 518), 'mouth_right': (903, 522)}}
# 3
# {'box': [1608, 837, 104, 127], 'confidence': 0.9999966025352478, 'keypoints': {'left_eye': (1636, 880), 'right_eye': (1685, 882), 'nose': (1659, 909), 'mouth_left': (1638, 930), 'mouth_right': (1680, 933)}}
# 4
# ...

# %%
filename = '/content/images (1).jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x, y, width, height = face['box']
  rect = plt.Rectangle((x, y), width, height,
                       fill = False, color = 'red')
  ax.add_patch(rect)  # chồng ảnh lên ảnh khác
  for key, value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color = 'green')
    ax.add_patch(dot)
    plt.savefig('/content/images (1).jpg')

plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 194ms/step

# %%
from PIL import Image
def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1, y1, width, height = result_list[i]['box']
    x2, y2 = x1 + width, y1 + height
    plt.subplot(1, len(result_list), i + 1)
    plt.axis('off')
    face_img = data[y1: y2, x1: x2]
    plt.imshow(face_img)
    plt.imsave(f'face_{i+1}.jpg', face_img)
  plt.show()

filename = '/content/Anh_lop.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename, faces)
# Out:
# 1/1 [==============================] - 1s 919ms/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f29286c81f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# 6/6 [==============================] - 0s 34ms/step
