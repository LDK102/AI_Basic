# %% [markdown]
# <a href="https://colab.research.google.com/github/LDK102/AI_Week3/blob/main/AI_Wk3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='Day1.csv'
dataframe = pd.read_csv(url)
dataframe.drop('Khoa', axis=1).head(20)
# Out:
#            MSSV       Unnamed: 1 Unnamed: 2      Điểm               Họ Và Tên
# 0   20146173.77           Lê Văn       Được  6.829333             Lê Văn Được
# 1   20146130.23       Trương Như        Hoa  7.545430          Trương Như Hoa
# 2   20146165.91        Phạm Thùy       Linh  3.121396          Phạm Thùy Linh
# 3   20146108.34       Nguyễn Thị       Ngọc  3.318933         Nguyễn Thị Ngọc
# 4   20146138.21  Nguyễn Thị Thảo     Nguyên  4.135105  Nguyễn Thị Thảo Nguyên
# 5   20146123.98  Nguyễn Thị Châu       Oanh  4.711640    Nguyễn Thị Châu Oanh
# 6   20146149.61         Phạm Thị     Phương  8.082376         Phạm Thị Phương
# 7   20146139.68     Tưởng Thị Hà      Trang  3.815439      Tưởng Thị Hà Trang
# 8   20146172.61  Nguyễn Thị Diễm       Hạnh  1.315283    Nguyễn Thị Diễm Hạnh
# 9   20146160.60      Bùi Thị Thu       Hiền  3.356237        Bùi Thị Thu Hiền
# 10  20146127.90     Phạm Thị Hòa         An  6.635337         Phạm Thị Hòa An
# ...

# %%
import pandas as pd
url='Day1.csv'
dataframe = pd.read_csv(url)
dataframe.drop(dataframe.columns[2:4], axis=1).head(20)
# Out:
#            MSSV       Unnamed: 1      Điểm               Họ Và Tên
# 0   20146173.77           Lê Văn  6.829333             Lê Văn Được
# 1   20146130.23       Trương Như  7.545430          Trương Như Hoa
# 2   20146165.91        Phạm Thùy  3.121396          Phạm Thùy Linh
# 3   20146108.34       Nguyễn Thị  3.318933         Nguyễn Thị Ngọc
# 4   20146138.21  Nguyễn Thị Thảo  4.135105  Nguyễn Thị Thảo Nguyên
# 5   20146123.98  Nguyễn Thị Châu  4.711640    Nguyễn Thị Châu Oanh
# 6   20146149.61         Phạm Thị  8.082376         Phạm Thị Phương
# 7   20146139.68     Tưởng Thị Hà  3.815439      Tưởng Thị Hà Trang
# 8   20146172.61  Nguyễn Thị Diễm  1.315283    Nguyễn Thị Diễm Hạnh
# 9   20146160.60      Bùi Thị Thu  3.356237        Bùi Thị Thu Hiền
# 10  20146127.90     Phạm Thị Hòa  6.635337         Phạm Thị Hòa An
# 11  20146101.52   Nguyễn Thị Như  4.183012      Nguyễn Thị Như Hậu
# 12  20146178.38        Trần Thị   3.555367         Trần Thị  Nghĩa
# ...

# %%
import pandas as pd
url='Day1.csv'
dataframe = pd.read_csv(url)
dataframe[dataframe.index!=4].head(20)
# Out:
#            MSSV       Unnamed: 1 Unnamed: 2  Khoa      Điểm  \
# 0   20146173.77           Lê Văn       Được  20.0  6.829333
# 1   20146130.23       Trương Như        Hoa  20.0  7.545430
# 2   20146165.91        Phạm Thùy       Linh  20.0  3.121396
# 3   20146108.34       Nguyễn Thị       Ngọc  20.0  3.318933
# 5   20146123.98  Nguyễn Thị Châu       Oanh  20.0  4.711640
# 6   20146149.61         Phạm Thị     Phương  20.0  8.082376
# 7   20146139.68     Tưởng Thị Hà      Trang  20.0  3.815439
# 8   20146172.61  Nguyễn Thị Diễm       Hạnh  20.0  1.315283
# 9   20146160.60      Bùi Thị Thu       Hiền  20.0  3.356237
# 10  20146127.90     Phạm Thị Hòa         An  20.0  6.635337
# 11  20146101.52   Nguyễn Thị Như        Hậu  20.0  4.183012
# 12  20146178.38        Trần Thị       Nghĩa  20.0  3.555367
# 13  20146187.44   Vương Thị Hạnh       Dung  20.0  6.837542
# 14  20146149.89           Ka Thị         Na  20.0  9.941070
# 15  20146128.27      Nguyễn Bảo         Hân  20.0  4.408162
# ...

# %%
import pandas as pd
import numpy as np

time_index = pd.date_range('01/01/2023',periods = 100000, freq='30s')
dataframe = pd.DataFrame(index = time_index)
dataframe ['Acess_Amount'] = np.random.randint(1,10,100000)
dataframe.resample('W').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14554
# 2023-01-08        100036
# 2023-01-15        101151
# 2023-01-22        100795
# 2023-01-29        101158
# 2023-02-05         82557

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
data = data.set_index(data['Medal']) #số huy chương BẠC
data.loc['Silver']
# Out:
#         Year      City     Sport      Discipline  NOC            Event  \
# Medal
# Silver  1924  Chamonix   Skating  Figure skating  AUT       individual
# Silver  1924  Chamonix  Biathlon        Biathlon  FIN  military patrol
# Silver  1924  Chamonix   Skating  Figure skating  FIN            pairs
# Silver  1924  Chamonix   Skating   Speed skating  FIN           10000m
# Silver  1924  Chamonix   Skating   Speed skating  FIN            5000m
# ...      ...       ...       ...             ...  ...              ...
# Silver  2006     Turin   Skating   Speed skating  USA            1000m
# Silver  2006     Turin   Skating   Speed skating  USA            1500m
# Silver  2006     Turin    Skiing       Snowboard  USA        Half-pipe
# Silver  2006     Turin    Skiing       Snowboard  USA        Half-pipe
# Silver  2006     Turin    Skiing       Snowboard  USA  Snowboard Cross
#
#        Event gender   Medal
# Medal
# Silver            M  Silver
# Silver            M  Silver
# ...

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
data = data.set_index(data['Medal']) #số huy chương Vàng
data.loc['Bronze']
# Out:
#         Year      City      Sport       Discipline  NOC  \
# Medal
# Bronze  1924  Chamonix  Bobsleigh        Bobsleigh  BEL
# Bronze  1924  Chamonix    Skating    Speed skating  FIN
# Bronze  1924  Chamonix    Skating    Speed skating  FIN
# Bronze  1924  Chamonix     Skiing  Cross Country S  FIN
# Bronze  1924  Chamonix   Biathlon         Biathlon  FRA
# ...      ...       ...        ...              ...  ...
# Bronze  2006     Turin    Skating   Short Track S.  USA
# Bronze  2006     Turin    Skating   Short Track S.  USA
# Bronze  2006     Turin    Skating    Speed skating  USA
# Bronze  2006     Turin     Skiing   Freestyle Ski.  USA
# Bronze  2006     Turin     Skiing        Snowboard  USA
#
#                         Event Event gender   Medal
# Medal
# Bronze               four-man            M  Bronze
# Bronze                   500m            M  Bronze
# Bronze    combined (4 events)            M  Bronze
# Bronze                   18km            M  Bronze
# ...

# %%
data = data.set_index(data['NOC']) #số huy chươNG CỦA NƯỚC ANH
data.loc['GBR']
# Out:
#      Year                    City       Sport      Discipline  NOC  \
# NOC
# GBR  1924                Chamonix   Bobsleigh       Bobsleigh  GBR
# GBR  1924                Chamonix     Curling         Curling  GBR
# GBR  1924                Chamonix  Ice Hockey      Ice Hockey  GBR
# GBR  1924                Chamonix     Skating  Figure skating  GBR
# GBR  1928              St. Moritz   Bobsleigh        Skeleton  GBR
# GBR  1936  Garmisch-Partenkirchen   Bobsleigh       Bobsleigh  GBR
# GBR  1936  Garmisch-Partenkirchen  Ice Hockey      Ice Hockey  GBR
# GBR  1936  Garmisch-Partenkirchen     Skating  Figure skating  GBR
# GBR  1948              St. Moritz   Bobsleigh        Skeleton  GBR
# GBR  1948              St. Moritz     Skating  Figure skating  GBR
# GBR  1952                    Oslo     Skating  Figure skating  GBR
# GBR  1964               Innsbruck   Bobsleigh       Bobsleigh  GBR
# GBR  1976               Innsbruck     Skating  Figure skating  GBR
# ...

# %%
data.groupby('Medal').count()
# Out:
#         Year  City  Sport  Discipline  NOC  Event  Event gender
# Medal
# Bronze   764   764    764         764  764    764           764
# Gold     774   774    774         774  774    774           774
# Silver   773   773    773         773  773    773           773

# %%
data[data['Medal']=='Gold'].head(2311)
# Out:
#      Year      City       Sport      Discipline  NOC            Event  \
# NOC
# AUT  1924  Chamonix     Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix     Skating  Figure skating  AUT            pairs
# CAN  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# FIN  1924  Chamonix     Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix     Skating   Speed skating  FIN            1500m
# ..    ...       ...         ...             ...  ...              ...
# USA  2006     Turin      Skiing   Alpine Skiing  USA  Alpine combined
# USA  2006     Turin      Skiing   Alpine Skiing  USA     giant slalom
# USA  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# USA  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# USA  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#     Event gender Medal
# NOC
# AUT            W  Gold
# AUT            X  Gold
# CAN            M  Gold
# ...

# %%
data[data['Medal']=='Bronze'].head(2604)
# Out:
#       Year      City      Sport       Discipline  NOC                  Event  \
# 3     1924  Chamonix  Bobsleigh        Bobsleigh  BEL               four-man
# 12    1924  Chamonix    Skating    Speed skating  FIN                   500m
# 13    1924  Chamonix    Skating    Speed skating  FIN    combined (4 events)
# 15    1924  Chamonix     Skiing  Cross Country S  FIN                   18km
# 16    1924  Chamonix   Biathlon         Biathlon  FRA        military patrol
# ...    ...       ...        ...              ...  ...                    ...
# 2291  2006     Turin    Skating   Short Track S.  USA                  1000m
# 2292  2006     Turin    Skating   Short Track S.  USA            5000m relay
# 2297  2006     Turin    Skating    Speed skating  USA                  1500m
# 2303  2006     Turin     Skiing   Freestyle Ski.  USA                 moguls
# 2304  2006     Turin     Skiing        Snowboard  USA  Giant parallel slalom
#
#      Event gender   Medal
# ...

# %%
data.groupby(['Medal','Event']).count()
# Out:
#                           Year  City  Sport  Discipline  NOC  Event gender
# Medal  Event
# Bronze 10000m               19    19     19          19   19            19
#        1000m                32    32     32          32   32            32
#        10km                 20    20     20          20   20            20
#        10km pursuit          6     6      6           6    6             6
#        12.5km mass start     1     1      1           1    1             1
# ...                        ...   ...    ...         ...  ...           ...
# Silver slalom               32    32     32          32   32            32
#        sprint                1     1      1           1    1             1
#        sprint 1.5km          1     1      1           1    1             1
#        super-G              13    13     13          13   13            13
#        two-man              18    18     18          18   18            18
#
# [201 rows x 6 columns]

# %%
import pandas as pandas
url= 'http://winterolympicsmedals.com/medals.csv'
data= pd.read_csv(url)
datas=data[(data['NOC'] =='GBR')]
print("Số huy chương của ENGLAND:",datas['Medal'].count())
# Out:
# Số huy chương của ENGLAND: 21

# %%
data1=data[(data['Event'] =='1000m') & (data['Medal']=='Bronze')] 
print("Số huy chương chương đồng theo môn cá nhân 1000m:",data1['Event'].count())
# Out:
# Số huy chương chương đồng theo môn cá nhân 1000m: 32

# %%
data1=data[(data['Event'] =='1000m') & (data['Medal']=='Silver')] 
print("Số huy chương chương bạc theo môn cá nhân 1000m:",data1['Event'].count())
# Out:
# Số huy chương chương bạc theo môn cá nhân 1000m: 31

# %%
data1=data[(data['Event'] =='1000m') & (data['Medal']=='Gold')] 
print("Số huy chương chương vàng theo môn cá nhân 1000m:",data1['Event'].count())
# Out:
# Số huy chương chương vàng theo môn cá nhân 1000m: 31
